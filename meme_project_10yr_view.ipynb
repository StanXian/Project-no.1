# %%
#Import modules and API key for Custom Search JSON API
import pandas as pd
import matplotlib.pyplot as plt

# %%
harambe_file = "harambe_file_y10.csv"
moth_file = "moth_lammp_meme_file_y10.csv"
fox_file = "what_does_the_fox_say_file_y10.csv"
alex_file = "alex_from_target_file_y10.csv"
fleek_file = "on_fleek_file_y10.csv"
covfefe_file = "covfefe_file_y10.csv"

harambe_file_df = pd.read_csv(harambe_file)
moth_file_df = pd.read_csv(moth_file)
fox_file_df = pd.read_csv(fox_file)
alex_file_df = pd.read_csv(alex_file)
fleek_file_df = pd.read_csv(fleek_file)
covfefe_file_df = pd.read_csv(covfefe_file)

# %%
combined_memes10y_df = pd.merge(harambe_file_df, moth_file_df, how='outer', on='Months')
combined_memes10y_df

combined_memes10y_df = combined_memes10y_df.rename(columns= {'Results_x': 'Harambe Meme', 'Results_y': 'Moth Lamp Meme'}) 
combined_memes10y_df

combined_memes10y_df = pd.merge(combined_memes10y_df, fox_file_df, how='outer', on='Months')
combined_memes10y_df

combined_memes10y_df = combined_memes10y_df.rename(columns= {'Results': 'Fox Say Meme'}) 
combined_memes10y_df

combined_memes10y_df = pd.merge(combined_memes10y_df, alex_file_df, how='outer', on='Months')
combined_memes10y_df

combined_memes10y_df = combined_memes10y_df.rename(columns= {'Results': 'Alex Target Meme'}) 
combined_memes10y_df

combined_memes10y_df = pd.merge(combined_memes10y_df, fleek_file_df, how='outer', on='Months')
combined_memes10y_df

combined_memes10y_df = combined_memes10y_df.rename(columns= {'Results': 'On Fleek Meme'}) 
combined_memes10y_df

combined_memes10y_df = pd.merge(combined_memes10y_df, covfefe_file_df, how='outer', on='Months')
combined_memes10y_df

combined_memes10y_df = combined_memes10y_df.rename(columns= {'Months': 'Year', 'Results': 'Covfefe Meme'}) 
combined_memes10y_df
# Out:
#   Year  Harambe Meme  Moth Lamp Meme  Fox Say Meme  Alex Target Meme  \
# 0   y1        202000         2580000     162000000          25000000
# 1   y2        811000         3870000     170000000          37100000
# 2   y3        765000         4420000     175000000          39600000
# 3   y4        673000         5070000     172000000          54900000
# 4   y5        681000         5000000     166000000          38700000
# 5   y6        720000         5270000     174000000          52200000
# 6   y7        728000         5090000     176000000          62500000
# 7   y8        768000         5010000     170000000          45800000
# 8   y9        774000         4900000     189000000          63400000
# 9  y10        779000         5610000     176000000          40100000
#
#    On Fleek Meme  Covfefe Meme
# 0        2820000        117000
# 1        2800000        124000
# 2        2930000        130000
# 3        2830000        134000
# 4        2840000        137000
# ...

# %%
plt.plot(combined_memes10y_df["Harambe Meme"])
plt.plot(combined_memes10y_df["Moth Lamp Meme"])
plt.plot(combined_memes10y_df["Fox Say Meme"])
plt.plot(combined_memes10y_df["Alex Target Meme"])
plt.plot(combined_memes10y_df["On Fleek Meme"])
plt.plot(combined_memes10y_df["Covfefe Meme"])

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
